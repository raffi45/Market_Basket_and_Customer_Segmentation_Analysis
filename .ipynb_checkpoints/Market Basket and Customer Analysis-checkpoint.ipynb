# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
from datetime import datetime
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('Transaction data.csv')
data.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB

# %%
data.describe()
# Out:
#                Price       Quantity     CustomerNo
# count  536350.000000  536350.000000  536295.000000
# mean       12.662182       9.919347   15227.893178
# std         8.490450     216.662300    1716.582932
# min         5.130000  -80995.000000   12004.000000
# 25%        10.990000       1.000000   13807.000000
# 50%        11.940000       3.000000   15152.000000
# 75%        14.090000      10.000000   16729.000000
# max       660.620000   80995.000000   18287.000000

# %% [markdown]
# ## PRE-PROCESSING

# %% [markdown]
# #### Check Mising Value

# %%
data.isnull().sum()
# Out:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %% [markdown]
# #### Cleaning data

# %%
data.dropna(inplace = True)
data.isnull().sum()
# Out:
# TransactionNo    0
# Date             0
# ProductNo        0
# ProductName      0
# Price            0
# Quantity         0
# CustomerNo       0
# Country          0
# dtype: int64

# %% [markdown]
# ### Check the distribution of countries

# %%
data.value_counts('Country').head(10)
# Out:
# Country
# United Kingdom    485040
# Germany            10675
# France             10526
# EIRE                8048
# Belgium             2539
# Spain               2430
# Switzerland         2336
# Netherlands         2330
# Portugal            1848
# Australia           1704
# dtype: int64

# %% [markdown]
# ## Data Filter for Germany

# %%
germany_data = data[data['Country'] == 'Germany']
germany_data.head()
# Out:
#     TransactionNo       Date ProductNo                        ProductName  \
# 914        581494  12/9/2019     23084                 Rabbit Night Light
# 915        581494  12/9/2019     21559  Strawberry Lunch Box With Cutlery
# 916        581494  12/9/2019     21506           Fancy Font Birthday Card
# 917        581494  12/9/2019     22716                 Card Circus Parade
# 918        581494  12/9/2019     22556      Plasters In Tin Circus Parade
#
#      Price  Quantity  CustomerNo  Country
# 914   6.19        24     12518.0  Germany
# 915   6.19         6     12518.0  Germany
# 916   6.19        12     12518.0  Germany
# 917   6.19        12     12518.0  Germany
# 918   6.19        12     12518.0  Germany

# %% [markdown]
# ## Market Basket Analysis (MBA)

# %% [markdown]
# ### Formatting Data for Market Basket Analysis

# %%
basket = germany_data.groupby(['TransactionNo', 'ProductName'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('TransactionNo')

def encode_units(x):
    if x <= 0:
        return 0
    else:
        return 1

basket = basket.applymap(encode_units)

basket.head()
# Out:
# ProductName    10 Colour Spaceboy Pen  12 Coloured Party Balloons  \
# TransactionNo
# 536527                              0                           0
# 536840                              0                           0
# 536861                              0                           0
# 536967                              0                           0
# 536983                              0                           0
#
# ProductName    12 Ivory Rose Peg Place Settings  \
# TransactionNo
# 536527                                        0
# 536840                                        0
# 536861                                        0
# 536967                                        0
# 536983                                        0
#
# ProductName    12 Message Cards With Envelopes  12 Pencil Small Tube Woodland  \
# TransactionNo
# 536527                                       0                              0
# 536840                                       0                              0
# 536861                                       0                              0
# 536967                                       0                              0
# 536983                                       0                              0
#
# ProductName    12 Pencils Small Tube Red Retrospot  \
# TransactionNo
# 536527                                           0
# 536840                                           0
# 536861                                           0
# 536967                                           0
# 536983                                           0
#
# ProductName    12 Pencils Small Tube Skull  12 Pencils Tall Tube Posy  \
# TransactionNo
# 536527                                   0                          0
# 536840                                   0                          0
# 536861                                   0                          0
# 536967                                   0                          0
# 536983                                   0                          0
#
# ProductName    12 Pencils Tall Tube Red Retrospot  \
# TransactionNo
# 536527                                          0
# 536840                                          0
# 536861                                          0
# 536967                                          0
# 536983                                          0
#
# ProductName    12 Pencils Tall Tube Skulls  ...  \
# TransactionNo                               ...
# 536527                                   0  ...
# 536840                                   0  ...
# 536861                                   0  ...
# 536967                                   0  ...
# 536983                                   0  ...
#
# ProductName    You're Confusing Me Metal Sign  Yuletide Images Gift Wrap Set  \
# TransactionNo
# 536527                                      0                              0
# 536840                                      0                              0
# 536861                                      0                              0
# 536967                                      0                              0
# 536983                                      0                              0
#
# ProductName    Zinc Box Sign Home  Zinc Folkart Sleigh Bells  \
# TransactionNo
# 536527                          0                          0
# 536840                          0                          0
# 536861                          0                          0
# 536967                          0                          0
# 536983                          0                          0
#
# ProductName    Zinc Heart Lattice Charger Large  \
# TransactionNo
# 536527                                        0
# 536840                                        0
# 536861                                        0
# 536967                                        0
# 536983                                        0
#
# ProductName    Zinc Heart Lattice T-Light Holder  Zinc Metal Heart Decoration  \
# TransactionNo
# 536527                                         0                            0
# 536840                                         0                            0
# 536861                                         0                            0
# 536967                                         0                            0
# 536983                                         0                            0
#
# ProductName    Zinc T-Light Holder Star Large  \
# TransactionNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
#
# ProductName    Zinc T-Light Holder Stars Small  \
# TransactionNo
# 536527                                       0
# 536840                                       0
# 536861                                       0
# 536967                                       0
# 536983                                       0
#
# ProductName    Zinc Willie Winkie Candle Stick
# TransactionNo
# 536527                                       0
# 536840                                       0
# 536861                                       0
# 536967                                       0
# 536983                                       0
#
# [5 rows x 2072 columns]

# %% [markdown]
# ### Market Basket Analysis with Apriori

# %%
# minimum support 0.01
frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)

frequent_itemsets.head()
# Out:
#     support                               itemsets
# 0  0.020443               (10 Colour Spaceboy Pen)
# 1  0.017036        (12 Pencil Small Tube Woodland)
# 2  0.011925  (12 Pencils Small Tube Red Retrospot)
# 3  0.015332        (12 Pencils Tall Tube Woodland)
# 4  0.010221              (20 Dolly Pegs Retrospot)

# %% [markdown]
# ### Computing Association Rules

# %%
# minimum confidence 0.2
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

rules.head()
# Out:
#                        antecedents                           consequents  \
# 0         (10 Colour Spaceboy Pen)                  (Spaceboy Lunch Box)
# 1  (12 Pencils Tall Tube Woodland)  (Round Snack Boxes Set Of4 Woodland)
# 2     (3 Hook Hanger Magic Garden)              (6 Ribbons Rustic Charm)
# 3     (3 Hook Hanger Magic Garden)   (Round Snack Boxes Set Of 4 Fruits)
# 4     (3 Hook Hanger Magic Garden)  (Round Snack Boxes Set Of4 Woodland)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.020443            0.080068  0.010221    0.500000  6.244681
# 1            0.015332            0.185690  0.010221    0.666667  3.590214
# 2            0.028961            0.086882  0.010221    0.352941  4.062284
# 3            0.028961            0.119250  0.011925    0.411765  3.452941
# 4            0.028961            0.185690  0.011925    0.411765  2.217485
#
#    leverage  conviction  zhangs_metric
# 0  0.008585    1.839864       0.857391
# 1  0.007374    2.442930       0.732699
# 2  0.007705    1.411182       0.776316
# 3  0.008471    1.497274       0.731579
# 4  0.006547    1.384327       0.565414

# %%
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
r
# 3125            0.017036  0.011925         1.0  58.700000  0.011722
# 3237            0.017036  0.010221         1.0  58.700000  0.010047
# 5066            0.017036  0.011925         1.0  58.700000  0.011722
# 5210            0.017036  0.010221         1.0  58.700000  0.010047
# 541             0.018739  0.017036         1.0  53.363636  0.016717
# 1267            0.018739  0.010221         1.0  53.363636  0.010030
# 2385            0.018739  0.011925         1.0  53.363636  0.011702
#
#       conviction  zhangs_metric
# 5179         inf       0.998279
# 5793         inf       0.998279
# 5795         inf       0.998279
# 5799         inf       0.998279
# 1480         inf       0.996558
# 3544         inf       0.996558
# 5067         inf       0.998276
# 576          inf       0.994836
# 613          inf       0.996552
# 3868         inf       0.994836
# 214          inf       0.993115
# 2842         inf       0.994828
# 2848         inf       0.994828
# 3125         inf       0.994828
# 3237         inf       0.993115
# 5066         inf       0.994828
# 5210         inf       0.993115
# 541          inf       0.998267
# 1267         inf       0.991394
# 2385         inf       0.993103

# %% [markdown]
# ### Visualisasi Hasil

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='support', y='confidence', size='lift', sizes=(10, 200), data=rules)
plt.title('Association Rules')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()

# %% [markdown]
# ## Convert 'Date' column to datetime data type

# %%
germany_data['Date'] = pd.to_datetime(germany_data['Date'])

# %% [markdown]
# ### Specify a Reference Date for Recency (last day of available data)

# %%
snapshot_date = germany_data['Date'].max() + dt.timedelta(days=1)

# %% [markdown]
# ### Counting Recency

# %%
recency_df = germany_data.groupby('CustomerNo').agg({
    'Date': lambda x: (snapshot_date - x.max()).days
}).reset_index()

recency_df.rename(columns={'Date': 'Recency'}, inplace=True)

recency_df.head()
# Out:
#    CustomerNo  Recency
# 0     12426.0      195
# 1     12427.0       12
# 2     12468.0      144
# 3     12471.0        3
# 4     12472.0       31

# %% [markdown]
# ### Counting Frequency

# %%
frequency_df = germany_data.groupby('CustomerNo').agg({
    'TransactionNo': 'count'
}).reset_index()

frequency_df.rename(columns={'TransactionNo': 'Frequency'}, inplace=True)

frequency_df.head()
# Out:
#    CustomerNo  Frequency
# 0     12426.0         29
# 1     12427.0         32
# 2     12468.0        371
# 3     12471.0        509
# 4     12472.0        384

# %% [markdown]
# ### Counting Monetary

# %%
germany_data['TotalPrice'] = germany_data['Price'] * germany_data['Quantity']
monetary_df = germany_data.groupby('CustomerNo').agg({
    'TotalPrice': 'sum'
}).reset_index()

monetary_df.rename(columns={'TotalPrice': 'Monetary'}, inplace=True)

monetary_df.head()
# Out:
#    CustomerNo  Monetary
# 0     12426.0   3126.61
# 1     12427.0   4176.45
# 2     12468.0  15984.73
# 3     12471.0  87408.68
# 4     12472.0  46128.88

# %% [markdown]
# ###  Merge Data

# %%
rfm = recency_df.merge(frequency_df, on='CustomerNo').merge(monetary_df, on='CustomerNo')
rfm.head()
# Out:
#    CustomerNo  Recency  Frequency  Monetary
# 0     12426.0      195         29   3126.61
# 1     12427.0       12         32   4176.45
# 2     12468.0      144        371  15984.73
# 3     12471.0        3        509  87408.68
# 4     12472.0       31        384  46128.88

# %% [markdown]
# ###  rank data and normalise data

# %%
rfm['R_rank'] = rfm['Recency'].rank(ascending=False) # low is good
rfm['F_rank'] = rfm['Frequency'].rank(ascending=True) # high is good
rfm['M_rank'] = rfm['Monetary'].rank(ascending=True) # high is good


rfm['R_rank_norm'] = (rfm['R_rank']/rfm['R_rank'].max())*100
rfm['F_rank_norm'] = (rfm['F_rank']/rfm['F_rank'].max())*100
rfm['M_rank_norm'] = (rfm['M_rank']/rfm['M_rank'].max())*100

rfm.drop(columns=['R_rank', 'F_rank', 'M_rank'], inplace=True)
rfm
# Out:
#     CustomerNo  Recency  Frequency  Monetary  R_rank_norm  F_rank_norm  \
# 0      12426.0      195         29   3126.61    13.259669    29.347826
# 1      12427.0       12         32   4176.45    79.558011    33.152174
# 2      12468.0      144        371  15984.73    18.784530    94.565217
# 3      12471.0        3        509  87408.68    93.922652    98.913043
# 4      12472.0       31        384  46128.88    50.828729    95.652174
# ..         ...      ...        ...       ...          ...          ...
# 87     13814.0       57         58  10435.52    40.883978    48.913043
# 88     13815.0       23        174  27348.55    65.193370    79.347826
# 89     13816.0       24         31   3118.90    60.773481    30.978261
# 90     13817.0       30         22   2345.98    52.486188    26.086957
# 91     14335.0       17         63   4096.70    75.690608    52.173913
#
#     M_rank_norm
# 0     30.434783
# 1     40.217391
# 2     70.652174
# 3    100.000000
# 4     91.304348
# ..          ...
# 87    57.608696
# 88    83.695652
# 89    29.347826
# 90    19.565217
# 91    39.130435
#
# [92 rows x 7 columns]

# %%
# Menghitung skor RFM gabungan
rfm['RFM_Score'] = 0.15 * rfm['R_rank_norm'] + 0.28 * rfm['F_rank_norm'] + 0.57 * rfm['M_rank_norm']
rfm['RFM_Score'] *= 0.05 # change it from 0-100 to score 0-5
rfm = rfm.round(2)
rfm[['CustomerNo', 'RFM_Score']]
rfm.head()
# Out:
#    CustomerNo  Recency  Frequency  Monetary  R_rank_norm  F_rank_norm  \
# 0     12426.0      195         29   3126.61        13.26        29.35
# 1     12427.0       12         32   4176.45        79.56        33.15
# 2     12468.0      144        371  15984.73        18.78        94.57
# 3     12471.0        3        509  87408.68        93.92        98.91
# 4     12472.0       31        384  46128.88        50.83        95.65
#
#    M_rank_norm  RFM_Score
# 0        30.43       1.38
# 1        40.22       2.21
# 2        70.65       3.48
# 3       100.00       4.94
# 4        91.30       4.32

# %% [raw]
# # Calculate RFM Score
#
# Rule of Thumb
#
# 1 – 3 scale for less than 30k customers;
# 1 – 4 scale for 30k – 200k customers;
# 1 – 5 scale for more than 200k customers.
# Formula used for calculating rfm score is : 0.15 Recency score + 0.28 Frequency score + 0.57 * Monetary score
#
# where 0.15,0.28,0.57 is a weight for each factor

# %% [markdown]
# # Create RFM Segmentation

# %%
# Define the function for RFM segmentation
def rfm_segment(df):
    if df['RFM_Score'] >= 2.5:
        return 'Best Customers'
    elif df['RFM_Score'] >= 1.5:
        return 'Loyal Customers'
    elif df['RFM_Score'] >= 1:
        return 'Potential Loyalists'
    else:
        return 'regular customers'

# Add segmentation column to RFM table
rfm['Customer_Segment'] = rfm.apply(rfm_segment, axis=1)

# Display the distribution of customer segments
rfm['Customer_Segment'].value_counts()
# Out:
# Best Customers         47
# Loyal Customers        19
# regular customers      16
# Potential Loyalists    10
# Name: Customer_Segment, dtype: int64

# %% [markdown]
# ### visualisation

# %%
plt.pie(rfm['Customer_Segment'].value_counts(),
        labels=rfm['Customer_Segment'].value_counts().index,
       autopct='%.1f%%')
plt.show()
